# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# %%
data = pd.read_csv("StockRatings-03.09.23.csv")

# %%
data
# Out:
#      Ticker                                 Company Market Cap  \
# 0         A              Agilent Technologies, Inc.     41.05B
# 1        AA                       Alcoa Corporation      8.80B
# 2      AAAU         Goldman Sachs Physical Gold ETF          -
# 3       AAC            Ares Acquisition Corporation    738.00M
# 4      AACG                   ATA Creativity Global     78.55M
# ...     ...                                     ...        ...
# 8314   ZVSA              ZyVersa Therapeutics, Inc.     21.23M
# 8315    ZWS  Zurn Elkay Water Solutions Corporation      3.99B
# 8316   ZYME                          Zymeworks Inc.    503.36M
# 8317   ZYNE           Zynerba Pharmaceuticals, Inc.     19.94M
# 8318   ZYXI                             Zynex, Inc.    359.55M
#
#       Overall Rating              Sector  \
# 0              69.56          Healthcare
# 1              51.96     Basic Materials
# 2              60.57           Financial
# 3              69.01           Financial
# 4              71.30  Consumer Defensive
# ...              ...                 ...
# 8314           75.33          Healthcare
# 8315           43.71         Industrials
# 8316           65.22          Healthcare
# 8317           64.29          Healthcare
# 8318           72.97          Healthcare
#
#                                       Industry Country Valuation Grade  \
# 0                       Diagnostics & Research     USA              C+
# 1                                     Aluminum     USA               B
# 2                         Exchange Traded Fund     USA              A+
# 3                              Shell Companies     USA               A
# 4                Education & Training Services   China               B
# ...                                        ...     ...             ...
# 8314                             Biotechnology     USA              A+
# 8315            Pollution & Treatment Controls     USA              C-
# 8316                             Biotechnology  Canada              A-
# 8317  Drug Manufacturers - Specialty & Generic     USA              A+
# 8318                      Medical Distribution     USA               B
#
#      Profitability Grade Growth Grade Performance Grade Fwd P/E   PEG    P/S  \
# 0                     B+           C+                B-   22.34  2.32   5.92
# 1                      D            C                 C    9.88     -   0.71
# 2                     D+           D+                C+       -     -      -
# 3                     C-           C-                 B       -     -      -
# 4                     D+            B                A-       -     -   2.70
# ...                  ...          ...               ...     ...   ...    ...
# 8314                  B-            C                B-       -     -      -
# 8315                   C           D+                C-   21.47  2.90   3.11
# 8316                  C-            C                B-       -     -  16.83
# 8317                   C           C+                D+       -     -      -
# 8318                  A-           C+                 C   18.65     -   2.40
#
#        P/B     P/C  P/FCF Dividend Payout Ratio EPS this Y EPS next Y  \
# 0     7.44       -  50.87    0.64%       18.90%      6.10%     10.83%
# 1     1.79    6.46  32.59    0.78%            -   -130.10%    113.92%
# 2        -       -      -        -            -          -          -
# 3     1.35       -      -        -        0.00%     32.40%          -
# 4     3.78    9.03      -        -            -     63.50%    -37.10%
# ...    ...     ...    ...      ...          ...        ...        ...
# 8314  0.30  106.15      -        -            -          -          -
# 8315  2.50   31.96  70.09    1.23%       40.20%     -7.30%     18.76%
# 8316  2.96    3.03      -        -            -    -14.70%   -196.80%
# 8317  0.36    0.36      -        -            -     50.00%     18.30%
# 8318  5.65   15.30  29.00        -        0.00%     84.80%     21.03%
#
#      EPS past 5Y EPS next 5Y Sales past 5Y   EPS Q/Q Sales Q/Q Insider Own  \
# 0         14.80%      13.67%         8.90%    26.90%     4.90%       0.30%
# 1        -19.70%      12.30%         1.30%    -3.60%   -20.30%       0.20%
# 2              -           -             -         -         -           -
# 3              -           -             -  -137.80%         -           -
# 4        -22.00%      25.00%       -15.60%    54.80%    -5.80%      18.70%
# ...          ...         ...           ...       ...       ...         ...
# 8314           -           -             -         -         -      55.90%
# 8315     -17.20%      17.00%        -7.10%   -85.80%   -62.60%       0.80%
# 8316     -24.10%      11.00%        19.40%    38.60%   -40.90%       0.10%
# 8317      18.10%           -             -    24.90%         -       2.70%
# 8318     193.30%           -        57.80%   -19.80%    19.30%      40.40%
#
#      Insider Trans Inst Own Inst Trans Short Ratio      ROA      ROE      ROI  \
# 0          -22.61%   90.70%     -3.31%        2.33   12.50%   25.00%   16.90%
# 1          -40.71%   82.60%     -5.84%        1.46   -0.80%   -2.40%    0.40%
# 2                -        -          -           -        -        -        -
# 3                -   92.10%      1.95%        1.23    2.10%    2.20%        -
# 4            0.00%   16.80%     -0.75%        0.39  -11.20%  -33.70%  -37.70%
# ...            ...      ...        ...         ...      ...      ...      ...
# 8314         0.00%   81.20%     16.14%        0.53   -2.60%   -2.70%        -
# 8315        -1.91%   78.70%      5.86%        2.79    3.10%    6.70%    3.70%
# 8316             -   78.40%     -0.58%        6.46  -60.30%  -96.10%  -86.30%
# 8317        -6.96%   23.70%     -0.96%        0.56  -50.30%  -58.20%        -
# 8318        -0.26%   29.70%     -2.79%       14.81   14.80%   26.00%   19.00%
#
#      Curr R Quick R LTDebt/Eq Debt/Eq Gross M   Oper M Profit M Perf Month  \
# 0      2.10    1.50      0.49    0.53  54.50%   24.10%   19.10%     -7.45%
# 1      1.70    0.90      0.36    0.36  18.00%    5.50%   -1.00%     -1.92%
# 2         -       -         -       -       -        -        -     -2.99%
# 3      0.00    0.00      0.00    0.00       -        -        -      0.69%
# 4      0.20    0.20      0.00    0.00  50.00%  -29.20%  -27.30%     44.78%
# ...     ...     ...       ...     ...     ...      ...      ...        ...
# 8314   0.30    0.30      0.00    0.00       -        -        -     -4.29%
# 8315   2.60    1.40      0.33    0.33  36.30%    8.40%    4.80%      1.75%
# 8316   3.30    3.30      0.00    0.00       -        -        -    -18.53%
# 8317   6.40    6.40      0.00    0.00       -        -        -    -29.51%
# 8318   3.40    2.70      0.10    0.19  80.10%   16.40%   12.30%    -25.41%
#
#      Perf Quart Perf Half Perf Year Perf YTD Volatility M    SMA20    SMA50  \
# 0        -7.73%     8.97%     8.10%   -5.85%        2.09%   -3.84%   -6.38%
# 1         9.67%     6.49%   -40.26%   12.21%        4.32%    2.38%    2.20%
# 2         2.60%     6.58%    -9.40%   -0.58%        0.74%   -1.50%   -2.84%
# 3         2.29%     3.64%     5.12%    1.89%        0.19%    0.37%    0.93%
# 4        60.26%     9.01%   101.67%   90.06%        8.08%   28.34%   51.69%
# ...         ...       ...       ...      ...          ...      ...      ...
# 8314    -78.16%   -77.45%         -   42.04%        9.87%    1.48%    2.83%
# 8315     -6.82%   -15.93%   -29.03%    7.28%        2.83%   -2.11%    1.68%
# 8316      4.99%    68.07%    28.00%    1.78%        5.50%   -6.90%   -8.53%
# 8317    -30.63%   -61.26%   -77.60%  -18.87%        9.51%  -18.60%  -23.41%
# 8318    -28.97%    10.02%    73.43%  -30.55%        4.29%  -23.24%  -30.75%
#
#        SMA200 52W High  52W Low    RSI  Earnings   Price Target Price  \
# 0       2.96%  -12.08%   25.22%  39.16  Feb 28/a  140.90       164.29
# 1       6.53%  -47.99%   52.07%  51.46  Jan 18/a   51.02        55.64
# 2       2.00%  -12.57%   12.02%  38.60         -   17.99            -
# 3       2.83%   -0.19%    5.34%  66.23         -   10.26            -
# 4      48.10%   -8.33%  175.09%  74.88         -    2.42        19.00
# ...       ...      ...      ...    ...       ...     ...          ...
# 8314  -68.78%  -91.08%   61.59%  47.34         -    2.23            -
# 8315  -11.23%  -38.38%   12.89%  48.81  Feb 07/a   22.69        27.33
# 8316   14.42%  -25.93%   94.65%  34.25  Mar 07/a    8.00        13.73
# 8317  -48.81%  -81.14%   -5.29%  34.37         -    0.43         5.44
# 8318  -10.33%  -44.00%   94.37%  16.70  Mar 06/a    9.66        22.50
#
#       Percent Diff
# 0        16.600426
# 1         9.055272
# 2              NaN
# 3              NaN
# 4       685.123967
# ...            ...
# 8314           NaN
# 8315     20.449537
# 8316     71.625000
# 8317   1165.116279
# 8318    132.919255
#
# [8319 rows x 57 columns]

# %%
len(list(data['Performance Grade'].unique()))
# Out:
# 13

# %%
data.sort_values("Overall Rating", ascending=False)
# Out:
#      Ticker                          Company Market Cap  Overall Rating  \
# 1728   CTRM             Castor Maritime Inc.     84.60M           95.48
# 510     ASC     Ardmore Shipping Corporation    770.98M           94.92
# 534    ASRT          Assertio Holdings, Inc.    266.53M           92.44
# 6138   QIPT         Quipt Home Medical Corp.    323.25M           91.20
# 6118   QIPT         Quipt Home Medical Corp.    323.25M           91.20
# ...     ...                              ...        ...             ...
# 8037    WHD                     Cactus, Inc.      3.73B           42.35
# 7425    TRP            TC Energy Corporation     40.72B           42.04
# 2395     EP     Empire Petroleum Corporation    300.64M           41.23
# 7551    UEC             Uranium Energy Corp.      1.21B           40.36
# 3710    ICE  Intercontinental Exchange, Inc.     57.47B           35.90
#
#            Sector                                  Industry  Country  \
# 1728  Industrials                           Marine Shipping   Cyprus
# 510   Industrials                           Marine Shipping  Bermuda
# 534    Healthcare  Drug Manufacturers - Specialty & Generic      USA
# 6138   Healthcare                           Medical Devices      USA
# 6118   Healthcare                           Medical Devices      USA
# ...           ...                                       ...      ...
# 8037       Energy            Oil & Gas Equipment & Services      USA
# 7425       Energy                       Oil & Gas Midstream   Canada
# 2395       Energy                             Oil & Gas E&P      USA
# 7551       Energy                                   Uranium      USA
# 3710    Financial          Financial Data & Stock Exchanges      USA
#
#      Valuation Grade Profitability Grade Growth Grade Performance Grade  \
# 1728               A                   A            B                A-
# 510               B+                   A           A-                B+
# 534               A-                   A           B-                A-
# 6138              B+                  B+           B+                 A
# 6118              B+                  B+           B+                 A
# ...              ...                 ...          ...               ...
# 8037              D+                  C-            C                D+
# 7425              C+                   D           D+                D+
# 2395              C+                   D           D+                C-
# 7551              A-                  D-            D                 D
# 3710              C-                  D+            D                D+
#
#      Fwd P/E    PEG   P/S    P/B    P/C  P/FCF Dividend Payout Ratio  \
# 1728       -      -  0.33   0.21   0.63   0.97        -        0.00%
# 510     9.86   0.13  1.73   1.61  15.24   6.21    2.42%        0.00%
# 534    11.06   0.44  1.91   2.13   4.11   4.76        -        0.00%
# 6138   25.66      -  1.57   2.16  64.65  14.56        -        0.00%
# 6118   25.66      -  1.57   2.16  64.65  14.56        -        0.00%
# ...      ...    ...   ...    ...    ...    ...      ...          ...
# 8037   15.76   1.94  5.42   4.97  10.84  59.36    0.94%       24.10%
# 7425    9.43  92.81  3.70   1.78      -  17.66    6.89%      713.30%
# 2395       -      -  5.43  11.58  19.15  17.28        -            -
# 7551       -      -  7.65   1.95      -      -        -        0.00%
# 3710   17.21   6.81  5.96   2.53  31.95  23.21    1.64%       58.80%
#
#      EPS this Y EPS next Y EPS past 5Y EPS next 5Y Sales past 5Y   EPS Q/Q  \
# 1728    283.30%          -           -           -             -   138.70%
# 510     413.20%    -35.81%      62.80%      42.64%        17.90%   614.00%
# 534      97.20%    -41.09%      65.20%      25.00%       -24.60%   -12.30%
# 6138    165.70%    303.12%      16.00%           -        12.90%   113.30%
# 6118    165.70%    303.12%      16.00%           -        12.90%   113.30%
# ...         ...        ...         ...         ...           ...       ...
# 8037    116.30%     17.08%      15.20%      13.40%        15.10%    99.50%
# 7425    -65.50%     -0.02%     -23.80%       0.87%         2.20%  -225.60%
# 2395     57.10%          -     -48.70%           -             -   104.00%
# 7551    126.60%      0.00%      16.40%           -             -   -32.70%
# 3710    -64.10%      9.76%      -2.80%       5.86%        10.50%   -72.00%
#
#      Sales Q/Q Insider Own Insider Trans Inst Own Inst Trans Short Ratio  \
# 1728    63.00%           -             -    1.40%    -11.63%        0.56
# 510    153.00%       9.87%         0.00%   67.50%     11.50%        2.39
# 534     34.10%       0.20%         0.00%   36.10%     28.16%        5.81
# 6138    38.30%       3.72%         0.00%   31.32%          -        4.81
# 6118    38.30%       3.72%         0.00%   31.32%          -        4.81
# ...        ...         ...           ...      ...        ...         ...
# 8037    44.60%      22.10%        -0.02%   99.30%     -2.85%        2.98
# 7425    12.80%       0.06%         0.00%   60.20%      5.34%        6.39
# 2395    46.50%      16.20%         6.64%   10.50%     57.44%       15.21
# 7551         -       1.80%         0.00%   46.10%      7.35%        5.82
# 3710     2.10%       0.20%       -17.94%   91.20%     -1.07%        1.59
#
#          ROA     ROE      ROI Curr R Quick R LTDebt/Eq Debt/Eq Gross M  \
# 1728  19.20%  26.80%   12.40%   3.70    3.50      0.25    0.32  75.60%
# 510   18.60%  35.80%   25.00%   3.00    2.70      0.34    0.37  52.00%
# 534    7.80%  21.50%    4.90%   1.40    1.20      0.49    0.51  87.80%
# 6138   5.80%   9.90%    6.00%   1.10    0.60      0.18    0.33  76.40%
# 6118   5.80%   9.90%    6.00%   1.10    0.60      0.18    0.33  76.40%
# ...      ...     ...      ...    ...     ...       ...     ...     ...
# 8037  10.20%  20.70%   24.50%   5.60    4.20      0.01    0.02  35.20%
# 7425   0.60%   2.10%    2.20%   0.40    0.40      1.59    1.85  67.10%
# 2395   1.30%   4.30%  -14.20%   1.90    1.70      0.27    0.33  45.90%
# 7551   0.80%   1.00%   -0.80%   3.10    1.50      0.00    0.00  21.40%
# 3710   0.70%   6.40%    8.10%   1.10    1.10      0.80    0.80  75.70%
#
#       Oper M Profit M Perf Month Perf Quart Perf Half Perf Year Perf YTD  \
# 1728  48.00%   40.50%     86.18%     52.97%    87.63%    27.75%  114.44%
# 510   36.20%   30.30%     20.36%     22.11%    87.10%   314.29%   28.80%
# 534   26.30%   18.40%     42.58%     81.16%   134.65%   162.56%   38.60%
# 6138   4.70%    4.80%     11.26%     52.89%    38.49%    59.13%   40.55%
# 6118   4.70%    4.80%     11.26%     52.89%    38.49%    59.13%   40.55%
# ...      ...      ...        ...        ...       ...       ...      ...
# 8037  25.40%   16.00%    -11.01%    -10.71%    12.64%   -22.46%   -6.92%
# 7425  17.20%    4.30%     -3.27%     -4.62%   -13.95%   -27.34%    1.63%
# 2395  20.00%    1.40%     -0.61%      2.61%   -10.18%    -4.63%    5.45%
# 7551   3.80%    2.30%    -12.01%     -5.07%   -19.76%   -26.42%  -13.14%
# 3710  37.70%   15.00%     -5.27%     -4.18%     2.70%   -22.49%    0.02%
#
#      Volatility M    SMA20    SMA50   SMA200 52W High  52W Low    RSI  \
# 1728        8.22%  -26.78%  -22.52%  -30.74%  -61.22%   -8.65%  87.43
# 510         5.01%    4.31%   19.64%   60.43%   -4.35%  387.14%  62.77
# 534         6.77%   13.39%   30.86%   78.62%   -8.49%  220.43%  66.26
# 6138        4.05%    5.24%   13.36%   33.01%   -0.15%   70.18%  68.87
# 6118        4.05%    5.24%   13.36%   33.01%   -0.15%   70.18%  68.87
# ...           ...      ...      ...      ...      ...      ...    ...
# 8037        4.36%   -6.22%   -9.10%   -0.14%  -27.11%   34.81%  39.47
# 7425        2.13%   -1.72%   -2.18%  -13.27%  -31.78%    5.63%  44.05
# 2395        3.89%    1.15%    2.90%   -5.40%  -47.91%   52.59%  52.94
# 7551        4.28%  -10.15%  -11.81%  -11.02%  -48.94%   15.41%  36.73
# 3710        1.82%   -2.54%   -3.00%    1.58%  -25.32%   15.81%  40.55
#
#       Earnings   Price Target Price  Percent Diff
# 1728         -    0.95            -           NaN
# 510   Feb 14/b   18.56        19.50      5.064655
# 534   Mar 08/a    5.96         7.88     32.214765
# 6138  Feb 13/a    6.62         9.61     45.166163
# 6118  Feb 13/a    6.62         9.61     45.166163
# ...        ...     ...          ...           ...
# 8037  Feb 22/a   46.78        54.33     16.139376
# 7425  Feb 14/b   40.51        50.58     24.858060
# 2395         -   12.97            -           NaN
# 7551  Dec 19/b    3.37         6.87    103.857567
# 3710  Feb 02/b  102.61       127.79     24.539519
#
# [8319 rows x 57 columns]

# %%
def matching_valuation(x):
    # print(x)
    standard_ratio = 10/11
    if x['Valuation Grade'] == "A+":
        return 11*standard_ratio
    elif x['Valuation Grade'] == "A":
        return 10*standard_ratio
    elif x['Valuation Grade'] == "A-":
        return 9*standard_ratio
    elif x['Valuation Grade'] == "B+":
        return 8*standard_ratio
    elif x['Valuation Grade'] == "B":
        return 7*standard_ratio
    elif x['Valuation Grade'] == "B-":
        return 6*standard_ratio
    elif x['Valuation Grade'] == "C+":
        return 5*standard_ratio
    elif x['Valuation Grade'] == "C":
        return 4*standard_ratio
    elif x['Valuation Grade'] == "C-":
        return 3*standard_ratio
    elif x['Valuation Grade'] == "D+":
        return 2*standard_ratio
    elif x['Valuation Grade'] == "D":
        return 1*standard_ratio

def matching_profitability(x):
    standard_ratio = 10/13
    if x['Profitability Grade'] == "A+":
        return 13*standard_ratio
    elif x['Profitability Grade'] == "A":
        return 12*standard_ratio
    elif x['Profitability Grade'] == "A-":
        return 11*standard_ratio
    elif x['Profitability Grade'] == "B+":
        return 10*standard_ratio
    elif x['Profitability Grade'] == "B":
        return 9*standard_ratio
    elif x['Profitability Grade'] == "B-":
        return 8*standard_ratio
    elif x['Profitability Grade'] == "C+":
        return 7*standard_ratio
    elif x['Profitability Grade'] == "C":
        return 6*standard_ratio
    elif x['Profitability Grade'] == "C-":
        return 5*standard_ratio
    elif x['Profitability Grade'] == "D+":
        return 4*standard_ratio
    elif x['Profitability Grade'] == "D":
        return 3*standard_ratio
    elif x['Profitability Grade'] == "D-":
        return 2*standard_ratio
    elif x['Profitability Grade'] == "F":
        return 1*standard_ratio
    
def matching_growth(x):
    standard_ratio = 10/13
    if x['Growth Grade'] == "A+":
        return 13*standard_ratio
    elif x['Growth Grade'] == "A":
        return 12*standard_ratio
    elif x['Growth Grade'] == "A-":
        return 11*standard_ratio
    elif x['Growth Grade'] == "B+":
        return 10*standard_ratio
    elif x['Growth Grade'] == "B":
        return 9*standard_ratio
    elif x['Growth Grade'] == "B-":
        return 8*standard_ratio
    elif x['Growth Grade'] == "C+":
        return 7*standard_ratio
    elif x['Growth Grade'] == "C":
        return 6*standard_ratio
    elif x['Growth Grade'] == "C-":
        return 5*standard_ratio
    elif x['Growth Grade'] == "D+":
        return 4*standard_ratio
    elif x['Growth Grade'] == "D":
        return 3*standard_ratio
    elif x['Growth Grade'] == "D-":
        return 2*standard_ratio
    elif x['Growth Grade'] == "F":
        return 1*standard_ratio
    

def matching_price_performance(x):
    standard_ratio = 10/13
    if x['Performance Grade'] == "A+":
        return 13*standard_ratio
    elif x['Performance Grade'] == "A":
        return 12*standard_ratio
    elif x['Performance Grade'] == "A-":
        return 11*standard_ratio
    elif x['Performance Grade'] == "B+":
        return 10*standard_ratio
    elif x['Performance Grade'] == "B":
        return 9*standard_ratio
    elif x['Performance Grade'] == "B-":
        return 8*standard_ratio
    elif x['Performance Grade'] == "C+":
        return 7*standard_ratio
    elif x['Performance Grade'] == "C":
        return 6*standard_ratio
    elif x['Performance Grade'] == "C-":
        return 5*standard_ratio
    elif x['Performance Grade'] == "D+":
        return 4*standard_ratio
    elif x['Performance Grade'] == "D":
        return 3*standard_ratio
    elif x['Performance Grade'] == "D-":
        return 2*standard_ratio
    elif x['Performance Grade'] == "F":
        return 1*standard_ratio

# %%
data['Valuation Grade']
# Out:
# 0       C+
# 1        B
# 2       A+
# 3        A
# 4        B
#         ..
# 8314    A+
# 8315    C-
# 8316    A-
# 8317    A+
# 8318     B
# Name: Valuation Grade, Length: 8319, dtype: object

# %%
data['Valuation Score'] = data.apply(lambda x: matching_valuation(x), axis = 1)
data['Profitability Score'] = data.apply(lambda x: matching_profitability(x), axis = 1)
data['Growth Score'] = data.apply(lambda x: matching_growth(x), axis = 1)
data['PricePerformance Score'] = data.apply(lambda x: matching_price_performance(x), axis = 1)

# %%
data
# Out:
#      Ticker                                 Company Market Cap  \
# 0         A              Agilent Technologies, Inc.     41.05B
# 1        AA                       Alcoa Corporation      8.80B
# 2      AAAU         Goldman Sachs Physical Gold ETF          -
# 3       AAC            Ares Acquisition Corporation    738.00M
# 4      AACG                   ATA Creativity Global     78.55M
# ...     ...                                     ...        ...
# 8314   ZVSA              ZyVersa Therapeutics, Inc.     21.23M
# 8315    ZWS  Zurn Elkay Water Solutions Corporation      3.99B
# 8316   ZYME                          Zymeworks Inc.    503.36M
# 8317   ZYNE           Zynerba Pharmaceuticals, Inc.     19.94M
# 8318   ZYXI                             Zynex, Inc.    359.55M
#
#       Overall Rating              Sector  \
# 0              69.56          Healthcare
# 1              51.96     Basic Materials
# 2              60.57           Financial
# 3              69.01           Financial
# 4              71.30  Consumer Defensive
# ...              ...                 ...
# 8314           75.33          Healthcare
# 8315           43.71         Industrials
# 8316           65.22          Healthcare
# 8317           64.29          Healthcare
# 8318           72.97          Healthcare
#
#                                       Industry Country Valuation Grade  \
# 0                       Diagnostics & Research     USA              C+
# 1                                     Aluminum     USA               B
# 2                         Exchange Traded Fund     USA              A+
# 3                              Shell Companies     USA               A
# 4                Education & Training Services   China               B
# ...                                        ...     ...             ...
# 8314                             Biotechnology     USA              A+
# 8315            Pollution & Treatment Controls     USA              C-
# 8316                             Biotechnology  Canada              A-
# 8317  Drug Manufacturers - Specialty & Generic     USA              A+
# 8318                      Medical Distribution     USA               B
#
#      Profitability Grade Growth Grade Performance Grade Fwd P/E   PEG    P/S  \
# 0                     B+           C+                B-   22.34  2.32   5.92
# 1                      D            C                 C    9.88     -   0.71
# 2                     D+           D+                C+       -     -      -
# 3                     C-           C-                 B       -     -      -
# 4                     D+            B                A-       -     -   2.70
# ...                  ...          ...               ...     ...   ...    ...
# 8314                  B-            C                B-       -     -      -
# 8315                   C           D+                C-   21.47  2.90   3.11
# 8316                  C-            C                B-       -     -  16.83
# 8317                   C           C+                D+       -     -      -
# 8318                  A-           C+                 C   18.65     -   2.40
#
#        P/B     P/C  P/FCF Dividend Payout Ratio EPS this Y EPS next Y  \
# 0     7.44       -  50.87    0.64%       18.90%      6.10%     10.83%
# 1     1.79    6.46  32.59    0.78%            -   -130.10%    113.92%
# 2        -       -      -        -            -          -          -
# 3     1.35       -      -        -        0.00%     32.40%          -
# 4     3.78    9.03      -        -            -     63.50%    -37.10%
# ...    ...     ...    ...      ...          ...        ...        ...
# 8314  0.30  106.15      -        -            -          -          -
# 8315  2.50   31.96  70.09    1.23%       40.20%     -7.30%     18.76%
# 8316  2.96    3.03      -        -            -    -14.70%   -196.80%
# 8317  0.36    0.36      -        -            -     50.00%     18.30%
# 8318  5.65   15.30  29.00        -        0.00%     84.80%     21.03%
#
#      EPS past 5Y EPS next 5Y Sales past 5Y   EPS Q/Q Sales Q/Q Insider Own  \
# 0         14.80%      13.67%         8.90%    26.90%     4.90%       0.30%
# 1        -19.70%      12.30%         1.30%    -3.60%   -20.30%       0.20%
# 2              -           -             -         -         -           -
# 3              -           -             -  -137.80%         -           -
# 4        -22.00%      25.00%       -15.60%    54.80%    -5.80%      18.70%
# ...          ...         ...           ...       ...       ...         ...
# 8314           -           -             -         -         -      55.90%
# 8315     -17.20%      17.00%        -7.10%   -85.80%   -62.60%       0.80%
# 8316     -24.10%      11.00%        19.40%    38.60%   -40.90%       0.10%
# 8317      18.10%           -             -    24.90%         -       2.70%
# 8318     193.30%           -        57.80%   -19.80%    19.30%      40.40%
#
#      Insider Trans Inst Own Inst Trans Short Ratio      ROA      ROE      ROI  \
# 0          -22.61%   90.70%     -3.31%        2.33   12.50%   25.00%   16.90%
# 1          -40.71%   82.60%     -5.84%        1.46   -0.80%   -2.40%    0.40%
# 2                -        -          -           -        -        -        -
# 3                -   92.10%      1.95%        1.23    2.10%    2.20%        -
# 4            0.00%   16.80%     -0.75%        0.39  -11.20%  -33.70%  -37.70%
# ...            ...      ...        ...         ...      ...      ...      ...
# 8314         0.00%   81.20%     16.14%        0.53   -2.60%   -2.70%        -
# 8315        -1.91%   78.70%      5.86%        2.79    3.10%    6.70%    3.70%
# 8316             -   78.40%     -0.58%        6.46  -60.30%  -96.10%  -86.30%
# 8317        -6.96%   23.70%     -0.96%        0.56  -50.30%  -58.20%        -
# 8318        -0.26%   29.70%     -2.79%       14.81   14.80%   26.00%   19.00%
#
#      Curr R Quick R LTDebt/Eq Debt/Eq Gross M   Oper M Profit M Perf Month  \
# 0      2.10    1.50      0.49    0.53  54.50%   24.10%   19.10%     -7.45%
# 1      1.70    0.90      0.36    0.36  18.00%    5.50%   -1.00%     -1.92%
# 2         -       -         -       -       -        -        -     -2.99%
# 3      0.00    0.00      0.00    0.00       -        -        -      0.69%
# 4      0.20    0.20      0.00    0.00  50.00%  -29.20%  -27.30%     44.78%
# ...     ...     ...       ...     ...     ...      ...      ...        ...
# 8314   0.30    0.30      0.00    0.00       -        -        -     -4.29%
# 8315   2.60    1.40      0.33    0.33  36.30%    8.40%    4.80%      1.75%
# 8316   3.30    3.30      0.00    0.00       -        -        -    -18.53%
# 8317   6.40    6.40      0.00    0.00       -        -        -    -29.51%
# 8318   3.40    2.70      0.10    0.19  80.10%   16.40%   12.30%    -25.41%
#
#      Perf Quart Perf Half Perf Year Perf YTD Volatility M    SMA20    SMA50  \
# 0        -7.73%     8.97%     8.10%   -5.85%        2.09%   -3.84%   -6.38%
# 1         9.67%     6.49%   -40.26%   12.21%        4.32%    2.38%    2.20%
# 2         2.60%     6.58%    -9.40%   -0.58%        0.74%   -1.50%   -2.84%
# 3         2.29%     3.64%     5.12%    1.89%        0.19%    0.37%    0.93%
# 4        60.26%     9.01%   101.67%   90.06%        8.08%   28.34%   51.69%
# ...         ...       ...       ...      ...          ...      ...      ...
# 8314    -78.16%   -77.45%         -   42.04%        9.87%    1.48%    2.83%
# 8315     -6.82%   -15.93%   -29.03%    7.28%        2.83%   -2.11%    1.68%
# 8316      4.99%    68.07%    28.00%    1.78%        5.50%   -6.90%   -8.53%
# 8317    -30.63%   -61.26%   -77.60%  -18.87%        9.51%  -18.60%  -23.41%
# 8318    -28.97%    10.02%    73.43%  -30.55%        4.29%  -23.24%  -30.75%
#
#        SMA200 52W High  52W Low    RSI  Earnings   Price Target Price  \
# 0       2.96%  -12.08%   25.22%  39.16  Feb 28/a  140.90       164.29
# 1       6.53%  -47.99%   52.07%  51.46  Jan 18/a   51.02        55.64
# 2       2.00%  -12.57%   12.02%  38.60         -   17.99            -
# 3       2.83%   -0.19%    5.34%  66.23         -   10.26            -
# 4      48.10%   -8.33%  175.09%  74.88         -    2.42        19.00
# ...       ...      ...      ...    ...       ...     ...          ...
# 8314  -68.78%  -91.08%   61.59%  47.34         -    2.23            -
# 8315  -11.23%  -38.38%   12.89%  48.81  Feb 07/a   22.69        27.33
# 8316   14.42%  -25.93%   94.65%  34.25  Mar 07/a    8.00        13.73
# 8317  -48.81%  -81.14%   -5.29%  34.37         -    0.43         5.44
# 8318  -10.33%  -44.00%   94.37%  16.70  Mar 06/a    9.66        22.50
#
#       Percent Diff  Valuation Score  Profitability Score  Growth Score  \
# 0        16.600426         4.545455             7.692308      5.384615
# 1         9.055272         6.363636             2.307692      4.615385
# 2              NaN        10.000000             3.076923      3.076923
# 3              NaN         9.090909             3.846154      3.846154
# 4       685.123967         6.363636             3.076923      6.923077
# ...            ...              ...                  ...           ...
# 8314           NaN        10.000000             6.153846      4.615385
# 8315     20.449537         2.727273             4.615385      3.076923
# 8316     71.625000         8.181818             3.846154      4.615385
# 8317   1165.116279        10.000000             4.615385      5.384615
# 8318    132.919255         6.363636             8.461538      5.384615
#
#       PricePerformance Score
# 0                   6.153846
# 1                   4.615385
# 2                   5.384615
# 3                   6.923077
# 4                   8.461538
# ...                      ...
# 8314                6.153846
# 8315                3.846154
# 8316                6.153846
# 8317                3.076923
# 8318                4.615385
#
# [8319 rows x 61 columns]

# %%
data.sort_values("Overall Rating", ascending=False)
# Out:
#      Ticker                          Company Market Cap  Overall Rating  \
# 1728   CTRM             Castor Maritime Inc.     84.60M           95.48
# 510     ASC     Ardmore Shipping Corporation    770.98M           94.92
# 534    ASRT          Assertio Holdings, Inc.    266.53M           92.44
# 6138   QIPT         Quipt Home Medical Corp.    323.25M           91.20
# 6118   QIPT         Quipt Home Medical Corp.    323.25M           91.20
# ...     ...                              ...        ...             ...
# 8037    WHD                     Cactus, Inc.      3.73B           42.35
# 7425    TRP            TC Energy Corporation     40.72B           42.04
# 2395     EP     Empire Petroleum Corporation    300.64M           41.23
# 7551    UEC             Uranium Energy Corp.      1.21B           40.36
# 3710    ICE  Intercontinental Exchange, Inc.     57.47B           35.90
#
#            Sector                                  Industry  Country  \
# 1728  Industrials                           Marine Shipping   Cyprus
# 510   Industrials                           Marine Shipping  Bermuda
# 534    Healthcare  Drug Manufacturers - Specialty & Generic      USA
# 6138   Healthcare                           Medical Devices      USA
# 6118   Healthcare                           Medical Devices      USA
# ...           ...                                       ...      ...
# 8037       Energy            Oil & Gas Equipment & Services      USA
# 7425       Energy                       Oil & Gas Midstream   Canada
# 2395       Energy                             Oil & Gas E&P      USA
# 7551       Energy                                   Uranium      USA
# 3710    Financial          Financial Data & Stock Exchanges      USA
#
#      Valuation Grade Profitability Grade Growth Grade Performance Grade  \
# 1728               A                   A            B                A-
# 510               B+                   A           A-                B+
# 534               A-                   A           B-                A-
# 6138              B+                  B+           B+                 A
# 6118              B+                  B+           B+                 A
# ...              ...                 ...          ...               ...
# 8037              D+                  C-            C                D+
# 7425              C+                   D           D+                D+
# 2395              C+                   D           D+                C-
# 7551              A-                  D-            D                 D
# 3710              C-                  D+            D                D+
#
#      Fwd P/E    PEG   P/S    P/B    P/C  P/FCF Dividend Payout Ratio  \
# 1728       -      -  0.33   0.21   0.63   0.97        -        0.00%
# 510     9.86   0.13  1.73   1.61  15.24   6.21    2.42%        0.00%
# 534    11.06   0.44  1.91   2.13   4.11   4.76        -        0.00%
# 6138   25.66      -  1.57   2.16  64.65  14.56        -        0.00%
# 6118   25.66      -  1.57   2.16  64.65  14.56        -        0.00%
# ...      ...    ...   ...    ...    ...    ...      ...          ...
# 8037   15.76   1.94  5.42   4.97  10.84  59.36    0.94%       24.10%
# 7425    9.43  92.81  3.70   1.78      -  17.66    6.89%      713.30%
# 2395       -      -  5.43  11.58  19.15  17.28        -            -
# 7551       -      -  7.65   1.95      -      -        -        0.00%
# 3710   17.21   6.81  5.96   2.53  31.95  23.21    1.64%       58.80%
#
#      EPS this Y EPS next Y EPS past 5Y EPS next 5Y Sales past 5Y   EPS Q/Q  \
# 1728    283.30%          -           -           -             -   138.70%
# 510     413.20%    -35.81%      62.80%      42.64%        17.90%   614.00%
# 534      97.20%    -41.09%      65.20%      25.00%       -24.60%   -12.30%
# 6138    165.70%    303.12%      16.00%           -        12.90%   113.30%
# 6118    165.70%    303.12%      16.00%           -        12.90%   113.30%
# ...         ...        ...         ...         ...           ...       ...
# 8037    116.30%     17.08%      15.20%      13.40%        15.10%    99.50%
# 7425    -65.50%     -0.02%     -23.80%       0.87%         2.20%  -225.60%
# 2395     57.10%          -     -48.70%           -             -   104.00%
# 7551    126.60%      0.00%      16.40%           -             -   -32.70%
# 3710    -64.10%      9.76%      -2.80%       5.86%        10.50%   -72.00%
#
#      Sales Q/Q Insider Own Insider Trans Inst Own Inst Trans Short Ratio  \
# 1728    63.00%           -             -    1.40%    -11.63%        0.56
# 510    153.00%       9.87%         0.00%   67.50%     11.50%        2.39
# 534     34.10%       0.20%         0.00%   36.10%     28.16%        5.81
# 6138    38.30%       3.72%         0.00%   31.32%          -        4.81
# 6118    38.30%       3.72%         0.00%   31.32%          -        4.81
# ...        ...         ...           ...      ...        ...         ...
# 8037    44.60%      22.10%        -0.02%   99.30%     -2.85%        2.98
# 7425    12.80%       0.06%         0.00%   60.20%      5.34%        6.39
# 2395    46.50%      16.20%         6.64%   10.50%     57.44%       15.21
# 7551         -       1.80%         0.00%   46.10%      7.35%        5.82
# 3710     2.10%       0.20%       -17.94%   91.20%     -1.07%        1.59
#
#          ROA     ROE      ROI Curr R Quick R LTDebt/Eq Debt/Eq Gross M  \
# 1728  19.20%  26.80%   12.40%   3.70    3.50      0.25    0.32  75.60%
# 510   18.60%  35.80%   25.00%   3.00    2.70      0.34    0.37  52.00%
# 534    7.80%  21.50%    4.90%   1.40    1.20      0.49    0.51  87.80%
# 6138   5.80%   9.90%    6.00%   1.10    0.60      0.18    0.33  76.40%
# 6118   5.80%   9.90%    6.00%   1.10    0.60      0.18    0.33  76.40%
# ...      ...     ...      ...    ...     ...       ...     ...     ...
# 8037  10.20%  20.70%   24.50%   5.60    4.20      0.01    0.02  35.20%
# 7425   0.60%   2.10%    2.20%   0.40    0.40      1.59    1.85  67.10%
# 2395   1.30%   4.30%  -14.20%   1.90    1.70      0.27    0.33  45.90%
# 7551   0.80%   1.00%   -0.80%   3.10    1.50      0.00    0.00  21.40%
# 3710   0.70%   6.40%    8.10%   1.10    1.10      0.80    0.80  75.70%
#
#       Oper M Profit M Perf Month Perf Quart Perf Half Perf Year Perf YTD  \
# 1728  48.00%   40.50%     86.18%     52.97%    87.63%    27.75%  114.44%
# 510   36.20%   30.30%     20.36%     22.11%    87.10%   314.29%   28.80%
# 534   26.30%   18.40%     42.58%     81.16%   134.65%   162.56%   38.60%
# 6138   4.70%    4.80%     11.26%     52.89%    38.49%    59.13%   40.55%
# 6118   4.70%    4.80%     11.26%     52.89%    38.49%    59.13%   40.55%
# ...      ...      ...        ...        ...       ...       ...      ...
# 8037  25.40%   16.00%    -11.01%    -10.71%    12.64%   -22.46%   -6.92%
# 7425  17.20%    4.30%     -3.27%     -4.62%   -13.95%   -27.34%    1.63%
# 2395  20.00%    1.40%     -0.61%      2.61%   -10.18%    -4.63%    5.45%
# 7551   3.80%    2.30%    -12.01%     -5.07%   -19.76%   -26.42%  -13.14%
# 3710  37.70%   15.00%     -5.27%     -4.18%     2.70%   -22.49%    0.02%
#
#      Volatility M    SMA20    SMA50   SMA200 52W High  52W Low    RSI  \
# 1728        8.22%  -26.78%  -22.52%  -30.74%  -61.22%   -8.65%  87.43
# 510         5.01%    4.31%   19.64%   60.43%   -4.35%  387.14%  62.77
# 534         6.77%   13.39%   30.86%   78.62%   -8.49%  220.43%  66.26
# 6138        4.05%    5.24%   13.36%   33.01%   -0.15%   70.18%  68.87
# 6118        4.05%    5.24%   13.36%   33.01%   -0.15%   70.18%  68.87
# ...           ...      ...      ...      ...      ...      ...    ...
# 8037        4.36%   -6.22%   -9.10%   -0.14%  -27.11%   34.81%  39.47
# 7425        2.13%   -1.72%   -2.18%  -13.27%  -31.78%    5.63%  44.05
# 2395        3.89%    1.15%    2.90%   -5.40%  -47.91%   52.59%  52.94
# 7551        4.28%  -10.15%  -11.81%  -11.02%  -48.94%   15.41%  36.73
# 3710        1.82%   -2.54%   -3.00%    1.58%  -25.32%   15.81%  40.55
#
#       Earnings   Price Target Price  Percent Diff  Valuation Score  \
# 1728         -    0.95            -           NaN         9.090909
# 510   Feb 14/b   18.56        19.50      5.064655         7.272727
# 534   Mar 08/a    5.96         7.88     32.214765         8.181818
# 6138  Feb 13/a    6.62         9.61     45.166163         7.272727
# 6118  Feb 13/a    6.62         9.61     45.166163         7.272727
# ...        ...     ...          ...           ...              ...
# 8037  Feb 22/a   46.78        54.33     16.139376         1.818182
# 7425  Feb 14/b   40.51        50.58     24.858060         4.545455
# 2395         -   12.97            -           NaN         4.545455
# 7551  Dec 19/b    3.37         6.87    103.857567         8.181818
# 3710  Feb 02/b  102.61       127.79     24.539519         2.727273
#
#       Profitability Score  Growth Score  PricePerformance Score
# 1728             9.230769      6.923077                8.461538
# 510              9.230769      8.461538                7.692308
# 534              9.230769      6.153846                8.461538
# 6138             7.692308      7.692308                9.230769
# 6118             7.692308      7.692308                9.230769
# ...                   ...           ...                     ...
# 8037             3.846154      4.615385                3.076923
# 7425             2.307692      3.076923                3.076923
# 2395             2.307692      3.076923                3.846154
# 7551             1.538462      2.307692                2.307692
# 3710             3.076923      2.307692                3.076923
#
# [8319 rows x 61 columns]

# %%
ticker = "ASC"
val = round(data.loc[data['Ticker']==ticker]['Valuation Score'].values[0], 2)
prof = round(data.loc[data['Ticker']==ticker]['Profitability Score'].values[0], 2)
growth = round(data.loc[data['Ticker']==ticker]['Growth Score'].values[0], 2)
price = round(data.loc[data['Ticker']==ticker]['PricePerformance Score'].values[0], 2)

fig = go.Figure(data=go.Scatterpolar(
  r=[val, prof, growth, price],
  theta=[f'Valuation Score: {val}',f'Profitability Score: {prof}',f'Growth Score: {growth}', f'Price Score: {price}'],
  fill='toself',
  name=f"Company: {ticker}"
))

fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[0,10],
      tickfont=dict(size=20))
  ),
  width=1200,
  height=600,
  showlegend=True,
  font=dict(size=25)
)

fig.show()

# %%
ticker = "ASC"
val = round(data.loc[data['Ticker']==ticker]['Valuation Score'].values[0], 2)
prof = round(data.loc[data['Ticker']==ticker]['Profitability Score'].values[0], 2)
growth = round(data.loc[data['Ticker']==ticker]['Growth Score'].values[0], 2)
price = round(data.loc[data['Ticker']==ticker]['PricePerformance Score'].values[0], 2)

fig = go.Figure(data=go.Scatterpolar(
  r=[val, prof, growth, price],
  theta=[f'Valuation Score: {val}',f'Profitability Score: {prof}',f'Growth Score: {growth}', f'Price Score: {price}'],
  fill='toself',
  name=f"Company: {ticker}"
))

fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[0,10],
      tickfont=dict(size=20))
  ),
  width=1200,
  height=600,
  showlegend=True,
  font=dict(size=25)
)

fig.show()
